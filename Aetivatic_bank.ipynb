# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Data

# %%
loan_data=pd.read_csv("D:/job/ML_Artivatic_dataset/ML_Artivatic_dataset/train_indessa.csv")
test_data=pd.read_csv("D:/job/ML_Artivatic_dataset/ML_Artivatic_dataset/test_indessa.csv")

# %%
loan_data
# Out:
#         member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 0        58189336      14350        14350          14350.0  36 months
# 1        70011223       4800         4800           4800.0  36 months
# 2        70255675      10000        10000          10000.0  36 months
# 3         1893936      15000        15000          15000.0  36 months
# 4         7652106      16000        16000          16000.0  36 months
# ...           ...        ...          ...              ...        ...
# 532423   31296187      20000        20000          20000.0  36 months
# 532424   29403184      12000        12000          12000.0  60 months
# 532425    7357607      18725        18725          18725.0  60 months
# 532426   23182668      21000        21000          21000.0  60 months
# 532427   46122259      10000        10000          10000.0  36 months
#
#        batch_enrolled  int_rate grade sub_grade  \
# 0                         19.19     E        E3
# 1          BAT1586599     10.99     B        B4
# 2          BAT1586599      7.26     A        A4
# 3          BAT4808022     19.72     D        D5
# 4          BAT2833642     10.64     B        B2
# ...               ...       ...   ...       ...
# 532423                    12.49     B        B5
# 532424     BAT2003848     14.99     C        C5
# 532425            NaN     20.80     E        E1
# 532426     BAT3193689     16.29     D        D2
# 532427     BAT4136152      6.39     A        A2
#
#                                 emp_title  ... collections_12_mths_ex_med  \
# 0                                   clerk  ...                        0.0
# 1              Human Resources Specialist  ...                        0.0
# 2                                  Driver  ...                        0.0
# 3       Us office of Personnel Management  ...                        0.0
# 4             LAUSD-HOLLYWOOD HIGH SCHOOL  ...                        0.0
# ...                                   ...  ...                        ...
# 532423                   Registered Nurse  ...                        0.0
# 532424                        Account Mgr  ...                        0.0
# 532425                      Comcast cable  ...                        0.0
# 532426                 Resident Physician  ...                        0.0
# 532427                Health Care Analyst  ...                        0.0
#
#        mths_since_last_major_derog  application_type  \
# 0                             74.0        INDIVIDUAL
# 1                              NaN        INDIVIDUAL
# 2                              NaN        INDIVIDUAL
# 3                              NaN        INDIVIDUAL
# 4                              NaN        INDIVIDUAL
# ...                            ...               ...
# 532423                         NaN        INDIVIDUAL
# 532424                         NaN        INDIVIDUAL
# 532425                         NaN        INDIVIDUAL
# 532426                         NaN        INDIVIDUAL
# 532427                         NaN        INDIVIDUAL
#
#        verification_status_joint last_week_pay acc_now_delinq tot_coll_amt  \
# 0                            NaN     26th week            0.0          0.0
# 1                            NaN      9th week            0.0          0.0
# 2                            NaN      9th week            0.0         65.0
# 3                            NaN    135th week            0.0          0.0
# 4                            NaN     96th week            0.0          0.0
# ...                          ...           ...            ...          ...
# 532423                       NaN     65th week            0.0          0.0
# 532424                       NaN     70th week            0.0          0.0
# 532425                       NaN      9th week            0.0          0.0
# 532426                       NaN     78th week            0.0          0.0
# 532427                       NaN     44th week            0.0          0.0
#
#        tot_cur_bal total_rev_hi_lim loan_status
# 0          28699.0          30800.0           0
# 1           9974.0          32900.0           0
# 2          38295.0          34900.0           0
# 3          55564.0          24700.0           0
# 4          47159.0          47033.0           0
# ...            ...              ...         ...
# 532423     83087.0          24800.0           0
# 532424    227812.0          17800.0           0
# 532425     26010.0          24200.0           1
# 532426     29197.0          23300.0           0
# 532427     47866.0          21700.0           0
#
# [532428 rows x 45 columns]

# %% [markdown]
# # Exploratory Data Analytics

# %%
loan_data.describe()
# Out:
#           member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count  5.324280e+05  532428.000000  532428.000000    532428.000000
# mean   3.500547e+07   14757.595722   14744.271291     14704.926696
# std    2.412148e+07    8434.420080    8429.139277      8441.290381
# min    7.047300e+04     500.000000     500.000000         0.000000
# 25%    1.086688e+07    8000.000000    8000.000000      8000.000000
# 50%    3.709590e+07   13000.000000   13000.000000     13000.000000
# 75%    5.848920e+07   20000.000000   20000.000000     20000.000000
# max    7.354484e+07   35000.000000   35000.000000     35000.000000
#
#             int_rate    annual_inc            dti    delinq_2yrs  \
# count  532428.000000  5.324250e+05  532428.000000  532412.000000
# mean       13.242969  7.502984e+04      18.138767       0.314448
# std         4.379611  6.519985e+04       8.369074       0.860045
# min         5.320000  1.200000e+03       0.000000       0.000000
# 25%         9.990000  4.500000e+04      11.930000       0.000000
# 50%        12.990000  6.500000e+04      17.650000       0.000000
# 75%        16.200000  9.000000e+04      23.950000       0.000000
# max        28.990000  9.500000e+06     672.520000      30.000000
#
#        inq_last_6mths  mths_since_last_delinq  ...  total_rec_late_fee  \
# count   532412.000000           259874.000000  ...       532428.000000
# mean         0.694603               34.055735  ...            0.394954
# std          0.997025               21.884797  ...            4.091546
# min          0.000000                0.000000  ...            0.000000
# 25%          0.000000               15.000000  ...            0.000000
# 50%          0.000000               31.000000  ...            0.000000
# 75%          1.000000               50.000000  ...            0.000000
# max         31.000000              180.000000  ...          358.680000
#
#           recoveries  collection_recovery_fee  collections_12_mths_ex_med  \
# count  532428.000000            532428.000000               532333.000000
# mean       45.717832                 4.859221                    0.014299
# std       409.647467                63.123361                    0.133005
# min         0.000000                 0.000000                    0.000000
# 25%         0.000000                 0.000000                    0.000000
# 50%         0.000000                 0.000000                    0.000000
# 75%         0.000000                 0.000000                    0.000000
# max     33520.270000              7002.190000                   16.000000
#
#        mths_since_last_major_derog  acc_now_delinq   tot_coll_amt  \
# count                132980.000000   532412.000000  490424.000000
# mean                     44.121462        0.005015     213.562222
# std                      22.198410        0.079117    1958.571538
# min                       0.000000        0.000000       0.000000
# 25%                      27.000000        0.000000       0.000000
# 50%                      44.000000        0.000000       0.000000
# 75%                      61.000000        0.000000       0.000000
# max                     180.000000       14.000000  496651.000000
#
#         tot_cur_bal  total_rev_hi_lim    loan_status
# count  4.904240e+05      4.904240e+05  532428.000000
# mean   1.395541e+05      3.208057e+04       0.236327
# std    1.539149e+05      3.805304e+04       0.424826
# min    0.000000e+00      0.000000e+00       0.000000
# 25%    2.983975e+04      1.400000e+04       0.000000
# 50%    8.066950e+04      2.370000e+04       0.000000
# 75%    2.084792e+05      3.980000e+04       0.000000
# max    8.000078e+06      9.999999e+06       1.000000
#
# [8 rows x 27 columns]

# %%
loan_data.columns
# Out:
# Index(['member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term',
#        'batch_enrolled', 'int_rate', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'pymnt_plan', 'desc', 'purpose', 'title', 'zip_code', 'addr_state',
#        'dti', 'delinq_2yrs', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'application_type', 'verification_status_joint', 'last_week_pay',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim',
#        'loan_status'],
#       dtype='object')

# %%
loan_data.isnull().sum()
# Out:
# member_id                           0
# loan_amnt                           0
# funded_amnt                         0
# funded_amnt_inv                     0
# term                                0
# batch_enrolled                  85149
# int_rate                            0
# grade                               0
# sub_grade                           0
# emp_title                       30833
# emp_length                      26891
# home_ownership                      0
# annual_inc                          3
# verification_status                 0
# pymnt_plan                          0
# desc                           456829
# purpose                             0
# title                              90
# zip_code                            0
# addr_state                          0
# dti                                 0
# delinq_2yrs                        16
# inq_last_6mths                     16
# mths_since_last_delinq         272554
# mths_since_last_record         450305
# open_acc                           16
# pub_rec                            16
# revol_bal                           0
# revol_util                        287
# total_acc                          16
# initial_list_status                 0
# total_rec_int                       0
# total_rec_late_fee                  0
# recoveries                          0
# collection_recovery_fee             0
# collections_12_mths_ex_med         95
# mths_since_last_major_derog    399448
# application_type                    0
# verification_status_joint      532123
# last_week_pay                       0
# acc_now_delinq                     16
# tot_coll_amt                    42004
# tot_cur_bal                     42004
# total_rev_hi_lim                42004
# loan_status                         0
# dtype: int64

# %%
loan_data['loan_status'].value_counts()
# Out:
# 0    406601
# 1    125827
# Name: loan_status, dtype: int64

# %%
corr_matrix = loan_data.copy()
for col in corr_matrix.columns:
    if corr_matrix[col].dtype == "O":
         corr_matrix[col] = corr_matrix[col].factorize(sort=True)[0]
corr_matrix = corr_matrix.corr(method="pearson")

# %%
corr_matrix
# Out:
#                              member_id  loan_amnt  funded_amnt  \
# member_id                     1.000000   0.065607     0.067888
# loan_amnt                     0.065607   1.000000     0.999276
# funded_amnt                   0.067888   0.999276     1.000000
# funded_amnt_inv               0.073426   0.997124     0.998041
# term                          0.069739   0.411912     0.411001
# batch_enrolled               -0.147912  -0.004556    -0.004942
# int_rate                     -0.141030   0.145037     0.145222
# grade                        -0.006592   0.150783     0.150598
# sub_grade                    -0.009556   0.156635     0.156370
# emp_title                     0.015508   0.002044     0.002243
# emp_length                   -0.026873  -0.019317    -0.019516
# home_ownership                0.004072  -0.194999    -0.194806
# annual_inc                    0.034649   0.330655     0.330493
# verification_status          -0.031231   0.280259     0.279780
# pymnt_plan                   -0.003284   0.003386     0.003394
# desc                         -0.429972  -0.048577    -0.050870
# purpose                      -0.057994  -0.156244    -0.157215
# title                        -0.284355  -0.131231    -0.132386
# zip_code                     -0.009227  -0.004989    -0.004962
# addr_state                    0.011574   0.015466     0.015644
# dti                           0.134179   0.041866     0.042699
# delinq_2yrs                   0.049956  -0.000454    -0.000171
# inq_last_6mths               -0.127644  -0.033693    -0.034298
# mths_since_last_delinq       -0.008538  -0.038069    -0.038058
# mths_since_last_record       -0.161942  -0.012130    -0.012119
# open_acc                      0.087966   0.197630     0.198078
# pub_rec                       0.080268  -0.080952    -0.080613
# revol_bal                     0.035607   0.333944     0.333785
# revol_util                   -0.053282   0.119956     0.120507
# total_acc                     0.030643   0.220704     0.220597
# initial_list_status           0.378012   0.087138     0.088728
# total_rec_int                -0.461192   0.532580     0.531616
# total_rec_late_fee           -0.075700   0.031374     0.031022
# recoveries                   -0.113868   0.073326     0.072895
# collection_recovery_fee      -0.072498   0.052995     0.052797
# collections_12_mths_ex_med    0.051447  -0.014822    -0.014663
# mths_since_last_major_derog   0.056741  -0.037226    -0.037214
# application_type              0.034882   0.011641     0.011686
# verification_status_joint     0.030980   0.011562     0.011603
# last_week_pay                 0.223070   0.018221     0.019028
# acc_now_delinq                0.017607   0.003196     0.003298
# tot_coll_amt                  0.026725  -0.019994    -0.019994
# tot_cur_bal                   0.007278   0.327957     0.327955
# total_rev_hi_lim              0.046108   0.307989     0.307988
# loan_status                  -0.489753  -0.095713    -0.097563
#
#                              funded_amnt_inv      term  batch_enrolled  \
# member_id                           0.073426  0.069739       -0.147912
# loan_amnt                           0.997124  0.411912       -0.004556
# funded_amnt                         0.998041  0.411001       -0.004942
# funded_amnt_inv                     1.000000  0.411672       -0.006019
# term                                0.411672  1.000000       -0.008615
# batch_enrolled                     -0.006019 -0.008615        1.000000
# int_rate                            0.145251  0.427560        0.024544
# grade                               0.148567  0.442300        0.003683
# sub_grade                           0.154285  0.451168        0.004710
# emp_title                           0.002512  0.017145       -0.003489
# emp_length                         -0.020095 -0.009509        0.002833
# home_ownership                     -0.194651 -0.109206       -0.000513
# annual_inc                          0.329495  0.058746       -0.003388
# verification_status                 0.280786  0.167713        0.009419
# pymnt_plan                          0.003311  0.000636        0.000199
# desc                               -0.064095 -0.062951        0.062824
# purpose                            -0.159809 -0.054541        0.010914
# title                              -0.135559 -0.060252        0.053339
# zip_code                           -0.004704 -0.029206        0.006244
# addr_state                          0.015874  0.025115       -0.002709
# dti                                 0.044952  0.104824       -0.016271
# delinq_2yrs                         0.000280 -0.000348       -0.009703
# inq_last_6mths                     -0.038378 -0.003663        0.015129
# mths_since_last_delinq             -0.035713 -0.006586        0.001922
# mths_since_last_record              0.007380  0.036142        0.016719
# open_acc                            0.198672  0.085095       -0.011553
# pub_rec                            -0.079552 -0.025911       -0.019736
# revol_bal                           0.331935  0.091658       -0.000244
# revol_util                          0.121167  0.085920        0.011976
# total_acc                           0.220762  0.101235       -0.005261
# initial_list_status                 0.092935  0.133236       -0.080723
# total_rec_int                       0.529116  0.381977        0.075636
# total_rec_late_fee                  0.027770  0.005276        0.011514
# recoveries                          0.071242  0.057592        0.015342
# collection_recovery_fee             0.050261  0.035693        0.008008
# collections_12_mths_ex_med         -0.014240 -0.003565       -0.009532
# mths_since_last_major_derog        -0.037181 -0.006913       -0.007864
# application_type                    0.011718  0.012259       -0.008397
# verification_status_joint           0.011621  0.011691       -0.007767
# last_week_pay                       0.021237  0.031449       -0.073900
# acc_now_delinq                      0.003473  0.005256       -0.003453
# tot_coll_amt                       -0.019995 -0.009502       -0.004497
# tot_cur_bal                         0.327981  0.109673        0.001044
# total_rev_hi_lim                    0.308022  0.064213       -0.003444
# loan_status                        -0.101877 -0.130959        0.073531
#
#                              int_rate     grade  sub_grade  emp_title  ...  \
# member_id                   -0.141030 -0.006592  -0.009556   0.015508  ...
# loan_amnt                    0.145037  0.150783   0.156635   0.002044  ...
# funded_amnt                  0.145222  0.150598   0.156370   0.002243  ...
# funded_amnt_inv              0.145251  0.148567   0.154285   0.002512  ...
# term                         0.427560  0.442300   0.451168   0.017145  ...
# batch_enrolled               0.024544  0.003683   0.004710  -0.003489  ...
# int_rate                     1.000000  0.954046   0.977230   0.017577  ...
# grade                        0.954046  1.000000   0.976595   0.019250  ...
# sub_grade                    0.977230  0.976595   1.000000   0.019821  ...
# emp_title                    0.017577  0.019250   0.019821   1.000000  ...
# emp_length                  -0.000205 -0.001467  -0.001408   0.090445  ...
# home_ownership               0.065105  0.063542   0.066592  -0.013113  ...
# annual_inc                  -0.072061 -0.063767  -0.065319   0.008517  ...
# verification_status          0.250903  0.228029   0.240637  -0.073838  ...
# pymnt_plan                   0.002026  0.002076   0.002043  -0.000980  ...
# desc                         0.016953 -0.033406  -0.031912  -0.007533  ...
# purpose                      0.149982  0.151027   0.154804   0.000253  ...
# title                        0.091508  0.050395   0.051902   0.053908  ...
# zip_code                    -0.001635 -0.005390  -0.005209  -0.013816  ...
# addr_state                   0.005921  0.006438   0.006990   0.014315  ...
# dti                          0.163206  0.170075   0.175448  -0.004729  ...
# delinq_2yrs                  0.056767  0.060987   0.062819   0.007311  ...
# inq_last_6mths               0.228596  0.216397   0.222600   0.005851  ...
# mths_since_last_delinq      -0.032966 -0.035692  -0.037133  -0.007957  ...
# mths_since_last_record       0.027094 -0.024233  -0.024843  -0.006763  ...
# open_acc                    -0.009115  0.000852   0.000259  -0.003366  ...
# pub_rec                      0.052291  0.060101   0.061596   0.004451  ...
# revol_bal                   -0.035814 -0.030076  -0.029337  -0.013511  ...
# revol_util                   0.269350  0.246056   0.256684  -0.003349  ...
# total_acc                   -0.037465 -0.032868  -0.034038  -0.011315  ...
# initial_list_status         -0.112556 -0.070570  -0.065930   0.011365  ...
# total_rec_int                0.445634  0.376971   0.388002  -0.004563  ...
# total_rec_late_fee           0.056141  0.052961   0.054171   0.002383  ...
# recoveries                   0.107292  0.090952   0.093565   0.002741  ...
# collection_recovery_fee      0.071187  0.063693   0.065274   0.003333  ...
# collections_12_mths_ex_med   0.013924  0.020667   0.020805   0.007584  ...
# mths_since_last_major_derog -0.013878 -0.004021  -0.005324   0.000908  ...
# application_type             0.010666  0.013751   0.014294  -0.001928  ...
# verification_status_joint    0.012960  0.015820   0.016288  -0.001762  ...
# last_week_pay               -0.019079  0.025561   0.026906   0.022770  ...
# acc_now_delinq               0.026984  0.028614   0.029467   0.003771  ...
# tot_coll_amt                 0.002744  0.007592   0.007609   0.001731  ...
# tot_cur_bal                 -0.091506 -0.085090  -0.087752  -0.001746  ...
# total_rev_hi_lim            -0.164408 -0.150622  -0.156058  -0.015420  ...
# loan_status                  0.002590 -0.056775  -0.056880  -0.017536  ...
#
#                              collections_12_mths_ex_med  \
# member_id                                      0.051447
# loan_amnt                                     -0.014822
# funded_amnt                                   -0.014663
# funded_amnt_inv                               -0.014240
# term                                          -0.003565
# batch_enrolled                                -0.009532
# int_rate                                       0.013924
# grade                                          0.020667
# sub_grade                                      0.020805
# emp_title                                      0.007584
# emp_length                                    -0.001951
# home_ownership                                 0.005362
# annual_inc                                    -0.003960
# verification_status                            0.012622
# pymnt_plan                                    -0.000417
# desc                                          -0.027435
# purpose                                        0.001710
# title                                         -0.018089
# zip_code                                      -0.001811
# addr_state                                     0.005616
# dti                                            0.001032
# delinq_2yrs                                    0.063426
# inq_last_6mths                                 0.007005
# mths_since_last_delinq                        -0.034682
# mths_since_last_record                        -0.021165
# open_acc                                       0.010917
# pub_rec                                        0.021157
# revol_bal                                     -0.022619
# revol_util                                    -0.036243
# total_acc                                      0.009888
# initial_list_status                            0.015682
# total_rec_int                                 -0.023869
# total_rec_late_fee                            -0.003390
# recoveries                                    -0.004788
# collection_recovery_fee                       -0.002556
# collections_12_mths_ex_med                     1.000000
# mths_since_last_major_derog                   -0.102308
# application_type                              -0.001394
# verification_status_joint                     -0.000812
# last_week_pay                                  0.019976
# acc_now_delinq                                 0.052459
# tot_coll_amt                                   0.053011
# tot_cur_bal                                   -0.010656
# total_rev_hi_lim                              -0.016556
# loan_status                                   -0.033922
#
#                              mths_since_last_major_derog  application_type  \
# member_id                                       0.056741          0.034882
# loan_amnt                                      -0.037226          0.011641
# funded_amnt                                    -0.037214          0.011686
# funded_amnt_inv                                -0.037181          0.011718
# term                                           -0.006913          0.012259
# batch_enrolled                                 -0.007864         -0.008397
# int_rate                                       -0.013878          0.010666
# grade                                          -0.004021          0.013751
# sub_grade                                      -0.005324          0.014294
# emp_title                                       0.000908         -0.001928
# emp_length                                      0.016412         -0.002207
# home_ownership                                  0.002680         -0.008752
# annual_inc                                     -0.039256         -0.006089
# verification_status                            -0.011241          0.007486
# pymnt_plan                                      0.001220         -0.000093
# desc                                           -0.027475         -0.008311
# purpose                                        -0.013664         -0.002761
# title                                          -0.020047         -0.006693
# zip_code                                        0.022897          0.002589
# addr_state                                     -0.001353          0.000555
# dti                                             0.028913          0.039487
# delinq_2yrs                                    -0.423864          0.000921
# inq_last_6mths                                  0.019156         -0.002272
# mths_since_last_delinq                          0.699173         -0.002063
# mths_since_last_record                          0.032133          0.001950
# open_acc                                        0.008122         -0.002622
# pub_rec                                         0.116167          0.004244
# revol_bal                                      -0.019559         -0.001485
# revol_util                                     -0.011957          0.008320
# total_acc                                      -0.047453         -0.001992
# initial_list_status                             0.007059          0.010832
# total_rec_int                                  -0.058309         -0.017241
# total_rec_late_fee                             -0.007711         -0.002023
# recoveries                                     -0.013307         -0.002672
# collection_recovery_fee                        -0.008602         -0.001843
# collections_12_mths_ex_med                     -0.102308         -0.001394
# mths_since_last_major_derog                     1.000000         -0.003520
# application_type                               -0.003520          1.000000
# verification_status_joint                      -0.002547          0.888471
# last_week_pay                                   0.007172          0.017962
# acc_now_delinq                                 -0.109442         -0.001518
# tot_coll_amt                                    0.029274          0.000364
# tot_cur_bal                                    -0.070526          0.004662
# total_rev_hi_lim                               -0.018727         -0.004329
# loan_status                                    -0.010214         -0.013133
#
#                              verification_status_joint  last_week_pay  \
# member_id                                     0.030980       0.223070
# loan_amnt                                     0.011562       0.018221
# funded_amnt                                   0.011603       0.019028
# funded_amnt_inv                               0.011621       0.021237
# term                                          0.011691       0.031449
# batch_enrolled                               -0.007767      -0.073900
# int_rate                                      0.012960      -0.019079
# grade                                         0.015820       0.025561
# sub_grade                                     0.016288       0.026906
# emp_title                                    -0.001762       0.022770
# emp_length                                   -0.002147      -0.002786
# home_ownership                               -0.007845       0.003550
# annual_inc                                   -0.007004       0.008255
# verification_status                           0.013918      -0.042318
# pymnt_plan                                   -0.000082      -0.000422
# desc                                         -0.007384      -0.231056
# purpose                                      -0.002285      -0.024075
# title                                        -0.005522      -0.175012
# zip_code                                      0.002757      -0.003265
# addr_state                                    0.000068       0.007606
# dti                                           0.046976       0.039043
# delinq_2yrs                                  -0.000567       0.024716
# inq_last_6mths                               -0.001318      -0.007918
# mths_since_last_delinq                       -0.000662      -0.007894
# mths_since_last_record                       -0.000251      -0.059112
# open_acc                                     -0.001069       0.033435
# pub_rec                                       0.004194       0.045611
# revol_bal                                    -0.001380      -0.003315
# revol_util                                    0.007946      -0.022132
# total_acc                                    -0.001338       0.033219
# initial_list_status                           0.008947       0.170362
# total_rec_int                                -0.015164      -0.165138
# total_rec_late_fee                           -0.001622      -0.027994
# recoveries                                   -0.002374       0.019902
# collection_recovery_fee                      -0.001637       0.011256
# collections_12_mths_ex_med                   -0.000812       0.019976
# mths_since_last_major_derog                  -0.002547       0.007172
# application_type                              0.888471       0.017962
# verification_status_joint                     1.000000       0.015833
# last_week_pay                                 0.015833       1.000000
# acc_now_delinq                               -0.001348       0.009746
# tot_coll_amt                                  0.000282       0.015357
# tot_cur_bal                                   0.004647      -0.003013
# total_rev_hi_lim                             -0.004218      -0.003356
# loan_status                                  -0.011648      -0.115247
#
#                              acc_now_delinq  tot_coll_amt  tot_cur_bal  \
# member_id                          0.017607      0.026725     0.007278
# loan_amnt                          0.003196     -0.019994     0.327957
# funded_amnt                        0.003298     -0.019994     0.327955
# funded_amnt_inv                    0.003473     -0.019995     0.327981
# term                               0.005256     -0.009502     0.109673
# batch_enrolled                    -0.003453     -0.004497     0.001044
# int_rate                           0.026984      0.002744    -0.091506
# grade                              0.028614      0.007592    -0.085090
# sub_grade                          0.029467      0.007609    -0.087752
# emp_title                          0.003771      0.001731    -0.001746
# emp_length                        -0.004321     -0.009305    -0.021397
# home_ownership                    -0.014474     -0.006213    -0.506661
# annual_inc                         0.014906      0.000196     0.416120
# verification_status                0.012586     -0.002579     0.063680
# pymnt_plan                        -0.000246     -0.000305     0.001083
# desc                              -0.011871     -0.014901     0.000335
# purpose                            0.002633      0.013967    -0.023207
# title                             -0.003661     -0.003831    -0.029329
# zip_code                          -0.006083      0.016012    -0.006061
# addr_state                         0.004490      0.000611    -0.004334
# dti                                0.007267     -0.016416    -0.014336
# delinq_2yrs                        0.133391      0.001720     0.065782
# inq_last_6mths                    -0.003681      0.013787     0.033267
# mths_since_last_delinq            -0.136883      0.032696    -0.094698
# mths_since_last_record            -0.016221     -0.065135    -0.028431
# open_acc                           0.017665      0.003453     0.243723
# pub_rec                            0.001331      0.036327    -0.074634
# revol_bal                         -0.000863     -0.029147     0.442235
# revol_util                        -0.027892     -0.043648     0.081794
# total_acc                          0.026256      0.027950     0.310433
# initial_list_status                0.003140      0.005601     0.033553
# total_rec_int                      0.001156     -0.019355     0.131922
# total_rec_late_fee                 0.002448     -0.003160     0.011786
# recoveries                         0.001148     -0.004684     0.004769
# collection_recovery_fee            0.000301     -0.002861     0.006069
# collections_12_mths_ex_med         0.052459      0.053011    -0.010656
# mths_since_last_major_derog       -0.109442      0.029274    -0.070526
# application_type                  -0.001518      0.000364     0.004662
# verification_status_joint         -0.001348      0.000282     0.004647
# last_week_pay                      0.009746      0.015357    -0.003013
# acc_now_delinq                     1.000000      0.000672     0.023985
# tot_coll_amt                       0.000672      1.000000    -0.006267
# tot_cur_bal                        0.023985     -0.006267     1.000000
# total_rev_hi_lim                   0.007547     -0.023475     0.380439
# loan_status                       -0.014415     -0.013165     0.014579
#
#                              total_rev_hi_lim  loan_status
# member_id                            0.046108    -0.489753
# loan_amnt                            0.307989    -0.095713
# funded_amnt                          0.307988    -0.097563
# funded_amnt_inv                      0.308022    -0.101877
# term                                 0.064213    -0.130959
# batch_enrolled                      -0.003444     0.073531
# int_rate                            -0.164408     0.002590
# grade                               -0.150622    -0.056775
# sub_grade                           -0.156058    -0.056880
# emp_title                           -0.015420    -0.017536
# emp_length                          -0.034179     0.028021
# home_ownership                      -0.151144    -0.003807
# annual_inc                           0.265846    -0.008596
# verification_status                  0.049269    -0.022152
# pymnt_plan                           0.000050     0.000125
# desc                                -0.010268     0.283338
# purpose                             -0.053710     0.059788
# title                               -0.049000     0.179560
# zip_code                            -0.030330     0.025329
# addr_state                           0.001706    -0.021528
# dti                                  0.067941    -0.134020
# delinq_2yrs                         -0.040001    -0.045717
# inq_last_6mths                       0.006220     0.087339
# mths_since_last_delinq              -0.024684     0.029236
# mths_since_last_record              -0.033476     0.073566
# open_acc                             0.319794    -0.065048
# pub_rec                             -0.099084    -0.048884
# revol_bal                            0.815859    -0.040051
# revol_util                          -0.115926    -0.047196
# total_acc                            0.251165    -0.002631
# initial_list_status                  0.051461    -0.229466
# total_rec_int                        0.071980     0.038344
# total_rec_late_fee                  -0.005502    -0.004353
# recoveries                           0.001163    -0.062084
# collection_recovery_fee              0.002447    -0.042823
# collections_12_mths_ex_med          -0.016556    -0.033922
# mths_since_last_major_derog         -0.018727    -0.010214
# application_type                    -0.004329    -0.013133
# verification_status_joint           -0.004218    -0.011648
# last_week_pay                       -0.003356    -0.115247
# acc_now_delinq                       0.007547    -0.014415
# tot_coll_amt                        -0.023475    -0.013165
# tot_cur_bal                          0.380439     0.014579
# total_rev_hi_lim                     1.000000    -0.019547
# loan_status                         -0.019547     1.000000
#
# [45 rows x 45 columns]

# %%
def impute_random_nan(Data,ColName):
#Impute random value from column to NaN values for numerical features   
   
    Data[ColName+"_random"]=Data[ColName]
    random_sample = Data[ColName].dropna().sample(Data[ColName].isnull().sum(),random_state=0,replace=True)
    random_sample.index = Data[Data[ColName].isnull()].index
    Data.loc[Data[ColName].isnull(),ColName+'_random']=random_sample

# %%
for Columns in ['inq_last_6mths','open_acc','total_acc','collections_12_mths_ex_med','acc_now_delinq','tot_coll_amt','tot_cur_bal','total_rev_hi_lim']:
    impute_random_nan(loan_data,Columns)

# %%
def impute_nan_create_category(DataFrame,ColName):
    #Impute Nan values as "unknowm" for category features
     DataFrame[ColName] = np.where(DataFrame[ColName].isnull(),"Unknown",DataFrame[ColName])

# %%
for Columns in ['emp_title','emp_length','batch_enrolled']:
    impute_nan_create_category(loan_data,Columns)

# %%
 columns=['term','grade','emp_title','emp_length','sub_grade','home_ownership','pymnt_plan','purpose','title','zip_code','addr_state','initial_list_status','application_type','last_week_pay','batch_enrolled']

# %%
for col in columns:
    #Creating codes for each category features
    loan_data[col]=loan_data[col].astype('category')
    loan_data[col] = loan_data[col].cat.codes

# %% [markdown]
# # Droping columns with a larger number of null values

# %%
new_loan_data=loan_data.drop(['desc','mths_since_last_delinq','verification_status','mths_since_last_record','mths_since_last_major_derog','verification_status_joint','annual_inc','delinq_2yrs','inq_last_6mths','open_acc','pub_rec','revol_util','total_acc','collections_12_mths_ex_med','acc_now_delinq','tot_coll_amt','tot_cur_bal','total_rev_hi_lim'],axis=1)

# %%
from sklearn import model_selection, preprocessing, feature_selection, ensemble, linear_model, metrics, decomposition

# %%
x_data=new_loan_data.drop(['loan_status'],axis=1)
y_data=new_loan_data[['loan_status']]

# %% [markdown]
# # Model Selection

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler

# %%
model = LogisticRegression()

# %%
under = RandomUnderSampler(random_state = 2)

# %%
X_under, y_under= under.fit_resample(x_data, y_data)

# %%
x_training_data, x_test_data, y_training_data, y_test_data = train_test_split(X_under, y_under, test_size = 0.3)

# %%
model.fit(x_training_data, y_training_data)
# Out:
# c:\users\dibin\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# c:\users\dibin\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %%
predictions = model.predict(x_test_data)

# %%
from sklearn.metrics import classification_report

# %%
report=classification_report(y_test_data, predictions)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.73      0.75     37984
#            1       0.74      0.78      0.76     37513
#
#     accuracy                           0.75     75497
#    macro avg       0.75      0.75      0.75     75497
# weighted avg       0.75      0.75      0.75     75497

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test_data, predictions))
# Out:
# [[27577 10407]
#  [ 8249 29264]]

# %%
from sklearn import svm

# %%
SVM = svm.LinearSVC()

# %%
SVM.fit(x_training_data, y_training_data)
# Out:
# c:\users\dibin\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# c:\users\dibin\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVC()

# %%
pred=SVM.predict(x_test_data)

# %%
report_svm=classification_report(y_test_data, pred)

# %%
print(report_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.85      0.78     37984
#            1       0.82      0.66      0.73     37513
#
#     accuracy                           0.76     75497
#    macro avg       0.77      0.76      0.75     75497
# weighted avg       0.77      0.76      0.75     75497

# %%
print(confusion_matrix(y_test_data, pred))
# Out:
# [[32433  5551]
#  [12855 24658]]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=0)

# %%
RF.fit(x_training_data, y_training_data)
# Out:
# c:\users\dibin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
pred_rf=RF.predict(x_test_data)

# %%
report_rf=classification_report(y_test_data, pred_rf)

# %%
print(report_rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.79      0.76     37984
#            1       0.77      0.73      0.75     37513
#
#     accuracy                           0.76     75497
#    macro avg       0.76      0.76      0.76     75497
# weighted avg       0.76      0.76      0.76     75497

# %%
print(confusion_matrix(y_test_data, pred_rf))
# Out:
# [[29827  8157]
#  [10178 27335]]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

# %%
metrics.plot_roc_curve(SVM, x_test_data, y_test_data)  
plt.show()

# %%
metrics.plot_roc_curve(RF, x_test_data, y_test_data)  
plt.show()

# %%
metrics.plot_roc_curve(model, x_test_data, y_test_data)  
plt.show()

# %% [markdown]
# ##svm is better roc and recall. So Svm can choosen as model
